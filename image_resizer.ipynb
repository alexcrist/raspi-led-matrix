# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
IMAGE_RATIO = 2
IMAGE = 'alex.jpg'

# %%
def show():
    plt.axis('off')
    plt.imshow(np.asarray(img))
    plt.show()

# %%
img = Image.open(IMAGE)
show()

img = img.rotate(90, expand=True)
show()

X_TRANSLATE = 65
width, height = img.size
img = img.crop((0, X_TRANSLATE, width, width / 2 + X_TRANSLATE))
show()

img = img.resize((64, 32))
show()

img = img.convert('RGB')
show()
